# %% [markdown]
# # Notebook demonstrating how to access Historical Fire Perimeter data from geoserver

# %% [markdown]
# This notebook demonstrates how to access **Historical Fire Perimeter** data from <a href = "https://sdge.sdsc.edu/geoserver">geoserver </a>using the <a href = "https://docs.geoserver.org/stable/en/user/services/wfs/basics.html">Web Feature Service (WFS)</a> specification.
#
# #### What dates are available?
# - California: 1878 - 2022
# - United States: 2006 - 2022

# %% [markdown]
# #### Where does the data come from?
#
# The historical fire perimeter data are from the following sources:
# - <a href = "https://frap.fire.ca.gov/">CAL FIRE FRAP Program</a>
# - <a href = "https://data-nifc.opendata.arcgis.com">NIFC</a>
# - <a href = "https://www.geomac.gov/">USGS GeoMAC</a>
# - <a href = "https://www.blm.gov/">BLM</a>

# %% [markdown]
# **References:**
#
# - WFS: https://docs.geoserver.org/latest/en/user/services/wfs/reference.html
# - cql filter: https://docs.geoserver.org/stable/en/user/tutorials/cql/cql_tutorial.html

# %% [markdown]
# <h3>Notebook Overview:</h3>
# <ol><a href='#all_attributes'><li>Display all attributes that can be queried</li></a>
#     <a href='#dixie'><li>Query by specific fire (ex. Dixie fire)</li></a>
#     <a href='#dates'><li>Query fire between particular dates and number of acres</li></a>
#     <a href='#bbox'><li>Query fire between particular dates, number of acres, and bounding box,</li></a>

# %%
# folium installation recommended for map plotting visualizations
# !pip install folium

# %%
import requests, json, folium
import geopandas as gpd

# %% [markdown]
# <a id='all_attributes'><h3>Display all attributes that can be queried</h3></a>

# %%
#let's take a look at the available attributes that are queryable in pandas

baseURL='https://firemap.sdsc.edu/geoserver/ows?'

selectionParameters = "service=WFS&version=2.0.0&request=DescribeFeatureType&typeName=WIFIRE:view_historical_fires&outputFormat=application%2Fjson" 

url = baseURL + selectionParameters

r = requests.get(url) 
data_dict = r.json()
d = data_dict['featureTypes'][0]['properties']
#d

df = gpd.GeoDataFrame(d).set_index('name').T
df
# Out:
# name             year   fire_name      agency       acres   mapmethod  \
# maxOccurs           1           1           1           1           1
# minOccurs           0           0           0           0           0
# nillable         True        True        True        True        True
# type       xsd:number  xsd:string  xsd:string  xsd:number  xsd:string
# localType      number      string      string      number      string
#
# name        inciwebid alarm_date cont_date    comments complex_name  \
# maxOccurs           1          1         1           1            1
# minOccurs           0          0         0           0            0
# nillable         True       True      True        True         True
# type       xsd:string   xsd:date  xsd:date  xsd:string   xsd:string
# localType      string       date      date      string       string
#
# name      perimeter_timestamp       cause              geom
# maxOccurs                   1           1                 1
# minOccurs                   0           0                 0
# nillable                 True        True              True
# type                 xsd:date  xsd:string  gml:MultiPolygon
# localType                date      string      MultiPolygon

# %% [markdown]
# ### This is a typical query reponse in geojson output

# %%
baseURL='https://firemap.sdsc.edu/geoserver/ows?'

selectionParameters = "service=WFS&version=2.0.0&request=GetFeature&typeName=WIFIRE:view_historical_fires&count=1&outputFormat=application%2Fjson" 

url = baseURL + selectionParameters

r = requests.get(url) 
data_dict = r.json()
#data_dict

# %% [markdown]
# <a id='dixie'><h3>Query by specific fire name (ex. Dixie fire)</h3></a>

# %%
fire_name='DIXIE' 
#fire_name='DIXIE FIRE'.replace(' ','%20') # can't have spaces in api call

baseURL='https://firemap.sdsc.edu/geoserver/ows?'

selectionParameters = f"service=WFS&version=2.0.0&request=GetFeature&typeName=WIFIRE:view_historical_fires&cql_filter=fire_name='{fire_name}'&outputFormat=application%2Fjson"

url = baseURL + selectionParameters
print(url)
r = requests.get(url) 
data_dict = r.json()
#data_dict

# make list of dictionaries containing id, perimeter coordinates, timestamp, etc
rows = [{'id':entry['id'],'fire_name':entry['properties']['fire_name'],'acres':entry['properties']['acres'],'geometry':entry['geometry'],'perimeter_timestamp':entry['properties']['perimeter_timestamp'],'year':entry['properties']['year'],'cause':entry['properties']['cause'],'comments':entry['properties']['comments']} for entry in data_dict['features']]

df = gpd.GeoDataFrame.from_dict(rows, orient='columns')
df

# note - Query for Dixie is returning all fires with that name which includes several older fires. 
# Requester should include year and maybe a bbox to make sure they get a specific fire.
# Out:
# https://firemap.sdsc.edu/geoserver/ows?service=WFS&version=2.0.0&request=GetFeature&typeName=WIFIRE:view_historical_fires&cql_filter=fire_name='DIXIE'&outputFormat=application%2Fjson
#                                                    id fire_name  \
# 0   view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 1   view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 2   view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 3   view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 4   view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 5   view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 6   view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 7   view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 8   view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 9   view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 10  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 11  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 12  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 13  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 14  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 15  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 16  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 17  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 18  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 19  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 20  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 21  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 22  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 23  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 24  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 25  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 26  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 27  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 28  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 29  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 30  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 31  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
# 32  view_historical_fires.fid-4d4628be_17e556d6fe0...     DIXIE
#
#             acres                                           geometry  \
# 0        8.639968  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 1       11.465830  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 2       70.284797  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 3             NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 4             NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 5             NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 6     8536.401599  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 7             NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 8             NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 9             NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 10  133304.879149  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 11            NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 12  220012.650597  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 13  231579.023183  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 14  226421.184843  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 15  227247.759491  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 16            NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 17  253365.246725  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 18            NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 19            NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 20            NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 21  517416.750176  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 22            NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 23            NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 24  604511.745697  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 25  626645.257994  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 26  705000.966677  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 27  714218.517212  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 28            NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 29            NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 30            NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 31            NaN  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 32  928740.548343  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
#
#    perimeter_timestamp  year    cause  \
# 0          2017-09-14Z  2017     None
# 1                 None  2011       11
# 2                 None  1989  Natural
# 3          2021-07-20Z  2021     None
# 4          2021-07-20Z  2021     None
# 5          2021-07-16Z  2021     None
# 6          2021-07-17Z  2021     None
# 7          2021-07-20Z  2021     None
# 8          2021-07-20Z  2021     None
# 9          2021-07-22Z  2021     None
# 10         2021-07-22Z  2021     None
# 11         2021-07-23Z  2021     None
# 12         2021-07-28Z  2021     None
# 13         2021-07-29Z  2021     None
# 14         2021-07-29Z  2021     None
# 15         2021-07-29Z  2021     None
# 16         2021-08-02Z  2021     None
# 17         2021-08-02Z  2021     None
# 18         2021-09-05Z  2021     None
# 19         2021-08-08Z  2021     None
# 20         2021-08-11Z  2021     None
# 21         2021-08-12Z  2021     None
# 22         2021-08-19Z  2021     None
# 23         2021-08-15Z  2021     None
# 24         2021-08-16Z  2021     None
# 25         2021-08-17Z  2021     None
# 26         2021-08-20Z  2021     None
# 27         2021-08-20Z  2021     None
# 28         2021-08-29Z  2021     None
# 29         2021-08-30Z  2021     None
# 30         2021-09-03Z  2021     None
# 31         2021-09-04Z  2021     None
# 32         2021-09-09Z  2021     None
#
#                                              comments
# 0                                  WFDSS;GPS / Ground
# 1                                       FRA/State DPA
# 2                                                None
# 3         Feather River Canyon near Cresta Powerhouse
# 4         Feather River Canyon near Cresta Powerhouse
# 5         Feather River Canyon near Cresta Powerhouse
# 6         Feather River Canyon near Cresta Powerhouse
# 7         Feather River Canyon near Cresta Powerhouse
# 8         Feather River Canyon near Cresta Powerhouse
# 9         Feather River Canyon near Cresta Powerhouse
# 10        Feather River Canyon near Cresta Powerhouse
# 11        Feather River Canyon near Cresta Powerhouse
# 12  Feather River Canyon near Cresta Powerhouse an...
# 13  Feather River Canyon near Cresta Powerhouse an...
# 14  Feather River Canyon near Cresta Powerhouse an...
# 15  Feather River Canyon near Cresta Powerhouse an...
# 16  Feather River Canyon near Cresta Powerhouse an...
# 17  Feather River Canyon near Cresta Powerhouse an...
# 18  Feather River Canyon near Cresta Powerhouse an...
# 19  Feather River Canyon near Cresta Powerhouse an...
# 20  Feather River Canyon near Cresta Powerhouse an...
# 21  Feather River Canyon near Cresta Powerhouse an...
# 22  Feather River Canyon near Cresta Powerhouse an...
# 23  Feather River Canyon near Cresta Powerhouse an...
# 24  Feather River Canyon near Cresta Powerhouse an...
# 25  Feather River Canyon near Cresta Powerhouse an...
# 26  Feather River Canyon near Cresta Powerhouse an...
# 27  Feather River Canyon near Cresta Powerhouse an...
# 28  Feather River Canyon near Cresta Powerhouse an...
# 29  Feather River Canyon near Cresta Powerhouse an...
# 30  Feather River Canyon near Cresta Powerhouse an...
# 31  Feather River Canyon near Cresta Powerhouse an...
# 32  Feather River Canyon near Cresta Powerhouse an...

# %% [markdown]
# ### Visualization fire perimeters

# %%
#Define coordinates of where we want to center our map
alert_coords = [39.871306,-121.389439]

#Create the map
my_map = folium.Map(location = alert_coords, zoom_start=7, width=500, height=250)

#GeoJSON alert marker overlays
folium.GeoJson(data_dict, name="geojson").add_to(my_map)   

#toggle layers
folium.LayerControl().add_to(my_map)  

#Display the map
#my_map

# %% [markdown]
# <a href = "https://nbviewer.org/github/BurnPro3D/data-api-notebooks/blob/main/access-historical-fire-perimeter-data.ipynb">view map using nbviewer</a>

# %% [markdown]
# <a id='dates'><h3>Query fire between particular dates and number of acres</h3></a>

# %%
start_year='2011'
end_year='2012'

min_acres = '19900'
max_acres = '20000'

baseURL='https://firemap.sdsc.edu/geoserver/ows?'

selectionParameters = f"service=WFS&version=2.0.0&request=GetFeature&typeName=WIFIRE:view_historical_fires&CQL_FILTER=year%20between%20{start_year}%20and%20{end_year}and%20acres%20between%20{min_acres}%20and%20{max_acres}&outputFormat=application%2Fjson"

url = baseURL + selectionParameters
print(url) 

r = requests.get(url) 
data_dict = r.json()
d = data_dict['features']
#d

# make list of dictionaries containing id, perimeter coordinates, timestamp, etc
rows = [{'id':entry['id'],'fire_name':entry['properties']['fire_name'],'acres':entry['properties']['acres'],'geometry':entry['geometry'],'perimeter_timestamp':entry['properties']['perimeter_timestamp'],'year':entry['properties']['year'],'cause':entry['properties']['cause'],'comments':entry['properties']['comments']} for entry in data_dict['features']]

df = gpd.GeoDataFrame.from_dict(rows, orient='columns')
df
# Out:
# https://firemap.sdsc.edu/geoserver/ows?service=WFS&version=2.0.0&request=GetFeature&typeName=WIFIRE:view_historical_fires&CQL_FILTER=year%20between%202011%20and%202012and%20acres%20between%2019900%20and%2020000&outputFormat=application%2Fjson
#                                                   id          fire_name  \
# 0  view_historical_fires.fid-4d4628be_17e556d6fe0...        Horseshoe 2
# 1  view_historical_fires.fid-4d4628be_17e556d6fe0...               Lion
# 2  view_historical_fires.fid-4d4628be_17e556d6fe0...               Lion
# 3  view_historical_fires.fid-4d4628be_17e556d6fe0...               Salt
# 4  view_historical_fires.fid-4d4628be_17e556d6fe0...              Jacks
# 5  view_historical_fires.fid-4d4628be_17e556d6fe0...  Wenatchee Complex
#
#       acres                                           geometry  \
# 0  19931.77  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 1  19902.55  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 2  19982.96  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 3  19920.80  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 4  19993.27  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 5  19999.60  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
#
#   perimeter_timestamp  year cause           comments
# 0         2011-05-13Z  2011  None  IR heat perimeter
# 1         2011-08-05Z  2011  None               None
# 2         2011-08-06Z  2011  None               None
# 3         2011-09-11Z  2011  None               None
# 4         2012-07-10Z  2012  None              WFDSS
# 5         2012-10-06Z  2012  None               None

# %% [markdown]
# ### Visualize perimeter on map

# %%
#Define coordinates of where we want to center our map
coords = [39.871306,-121.389439]

#Create the map
my_map = folium.Map(location = coords, zoom_start=4, width=500, height=250)

#GeoJSON marker overlays
folium.GeoJson(data_dict, name="geojson").add_to(my_map)   

#toggle layers
folium.LayerControl().add_to(my_map)  

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_8ad8da21048a424db07c73d3edad4c8b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20500.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20250.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8ad8da21048a424db07c73d3edad4c8b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8ad8da21048a424db07c73d3edad4c8b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_8ad8da21048a424db07c73d3edad4c8b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.871306%2C%20-121.389439%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# <a href = "https://nbviewer.org/github/BurnPro3D/data-api-notebooks/blob/main/access-historical-fire-perimeter-data.ipynb">view map using nbviewer</a>

# %% [markdown]
# <a id='bbox'><h3>Query fire between particular dates, number of acres, and bbox</h3></a>

# %%
# define start/end year, min/max acres, and lat/long coordinates for the bounding box
start_year='2011'
end_year='2015'

min_acres = '10000'
max_acres = '20000'

min_Longitude, min_Latitude, max_Longitude, max_Latitude = -122.09596,39.66970,-120.336939,41.259914

baseURL='https://firemap.sdsc.edu/geoserver/ows?'

selectionParameters = f"service=WFS&version=2.0.0&request=GetFeature&typeName=WIFIRE:view_historical_fires&CQL_FILTER=year%20between%20{start_year}%20and%20{end_year}and%20acres%20between%20{min_acres}%20and%20{max_acres}and%28BBOX%28geom,{min_Longitude},%20{min_Latitude},%20{max_Longitude},%20{max_Latitude},%20%27EPSG:4269%27%20%29%29&outputFormat=application%2Fjson"

url = baseURL + selectionParameters
print(url) 

r = requests.get(url) 
data_dict = r.json()
d = data_dict['features']
#d

# make list of dictionaries containing id, perimeter coordinates, timestamp, etc
rows = [{'id':entry['id'],'fire_name':entry['properties']['fire_name'],'acres':entry['properties']['acres'],'geometry':entry['geometry'],'perimeter_timestamp':entry['properties']['perimeter_timestamp'],'year':entry['properties']['year'],'cause':entry['properties']['cause'],'comments':entry['properties']['comments']} for entry in data_dict['features']]

df = gpd.GeoDataFrame.from_dict(rows, orient='columns')
df
# Out:
# https://firemap.sdsc.edu/geoserver/ows?service=WFS&version=2.0.0&request=GetFeature&typeName=WIFIRE:view_historical_fires&CQL_FILTER=year%20between%202011%20and%202015and%20acres%20between%2010000%20and%2020000and%28BBOX%28geom,-122.09596,%2039.6697,%20-120.336939,%2041.259914,%20%27EPSG:4269%27%20%29%29&outputFormat=application%2Fjson
#                                                    id       fire_name  \
# 0   view_historical_fires.fid-4d4628be_17e556d6fe0...  Bagley Complex
# 1   view_historical_fires.fid-4d4628be_17e556d6fe0...          Likely
# 2   view_historical_fires.fid-4d4628be_17e556d6fe0...           Chips
# 3   view_historical_fires.fid-4d4628be_17e556d6fe0...         Reading
# 4   view_historical_fires.fid-4d4628be_17e556d6fe0...         Reading
# 5   view_historical_fires.fid-4d4628be_17e556d6fe0...           Chips
# 6   view_historical_fires.fid-4d4628be_17e556d6fe0...  Bagley Complex
# 7   view_historical_fires.fid-4d4628be_17e556d6fe0...  Bagley Complex
# 8   view_historical_fires.fid-4d4628be_17e556d6fe0...         Reading
# 9   view_historical_fires.fid-4d4628be_17e556d6fe0...            Deer
# 10  view_historical_fires.fid-4d4628be_17e556d6fe0...            Deer
# 11  view_historical_fires.fid-4d4628be_17e556d6fe0...            Deer
# 12  view_historical_fires.fid-4d4628be_17e556d6fe0...            Deer
# 13  view_historical_fires.fid-4d4628be_17e556d6fe0...            Deer
# 14  view_historical_fires.fid-4d4628be_17e556d6fe0...            Deer
# 15  view_historical_fires.fid-4d4628be_17e556d6fe0...            Deer
# 16  view_historical_fires.fid-4d4628be_17e556d6fe0...            Deer
# 17  view_historical_fires.fid-4d4628be_17e556d6fe0...            Deer
# 18  view_historical_fires.fid-4d4628be_17e556d6fe0...             Day
# 19  view_historical_fires.fid-4d4628be_17e556d6fe0...             Day
# 20  view_historical_fires.fid-4d4628be_17e556d6fe0...             Day
# 21  view_historical_fires.fid-4d4628be_17e556d6fe0...             Day
# 22  view_historical_fires.fid-4d4628be_17e556d6fe0...        H 1 Bald
# 23  view_historical_fires.fid-4d4628be_17e556d6fe0...             Day
# 24  view_historical_fires.fid-4d4628be_17e556d6fe0...            Bald
# 25  view_historical_fires.fid-4d4628be_17e556d6fe0...             Day
# 26  view_historical_fires.fid-4d4628be_17e556d6fe0...             Day
# 27  view_historical_fires.fid-4d4628be_17e556d6fe0...             Day
# 28  view_historical_fires.fid-4d4628be_17e556d6fe0...             Day
# 29  view_historical_fires.fid-4d4628be_17e556d6fe0...             Day
# 30  view_historical_fires.fid-4d4628be_17e556d6fe0...             Day
# 31  view_historical_fires.fid-4d4628be_17e556d6fe0...            DEER
# 32  view_historical_fires.fid-4d4628be_17e556d6fe0...             DAY
#
#            acres                                           geometry  \
# 0   15101.230000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 1   10061.890000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 2   18521.360000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 3   15497.600000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 4   12533.430000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 5   18228.050000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 6   11060.080000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 7   13711.390000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 8   19550.160000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 9   11515.990000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 10  10991.120000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 11  11428.750000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 12  11262.560000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 13  10274.410000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 14  10274.410000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 15  11444.510000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 16  11388.120000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 17  11428.750000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 18  13150.670000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 19  13047.720000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 20  11991.390000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 21  11947.090000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 22  17982.650000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 23  12289.310000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 24  17977.120000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 25  13028.180000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 26  13150.670000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 27  13047.720000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 28  13150.670000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 29  13047.720000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 30  13150.670000  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 31  11428.752930  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 32  13150.666016  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
#
#    perimeter_timestamp  year cause                  comments
# 0          2012-08-25Z  2012  None                      None
# 1          2012-09-10Z  2012  None                      FIMT
# 2          2012-08-09Z  2012  None                      FIMT
# 3          2012-08-12Z  2012  None                      None
# 4          2012-08-11Z  2012  None                      None
# 5          2012-08-08Z  2012  None                      FIMT
# 6          2012-08-24Z  2012  None         IR heat perimeter
# 7          2012-08-25Z  2012  None         IR heat perimeter
# 8          2012-08-13Z  2012  None                      None
# 9          2013-08-26Z  2013  None         IR heat perimeter
# 10         2013-08-26Z  2013  None                      None
# 11         2013-08-28Z  2013  None                      None
# 12         2013-08-24Z  2013  None         IR heat perimeter
# 13         2013-08-25Z  2013  None                      None
# 14         2013-08-24Z  2013  None                      None
# 15         2013-08-28Z  2013  None         IR heat perimeter
# 16         2013-08-26Z  2013  None         IR heat perimeter
# 17         2013-08-29Z  2013  None                      None
# 18         2014-08-07Z  2014  None                      None
# 19         2014-08-07Z  2014  None         IR heat perimeter
# 20         2014-08-01Z  2014  None         IR heat perimeter
# 21         2014-08-02Z  2014  None                      None
# 22         2014-08-02Z  2014  None  WFDSS; IR heat perimeter
# 23         2014-08-03Z  2014  None                      None
# 24         2014-08-01Z  2014  None         IR heat perimeter
# 25         2014-08-02Z  2014  None         IR heat perimeter
# 26         2014-08-06Z  2014  None                      None
# 27         2014-08-03Z  2014  None         IR heat perimeter
# 28         2014-08-04Z  2014  None                      None
# 29         2014-08-06Z  2014  None         IR heat perimeter
# 30         2014-08-07Z  2014  None                      None
# 31                None  2013     9                      None
# 32                None  2014     1                      None

# %% [markdown]
# ## visualize perimeters on map

# %%
#Define coordinates of where we want to center our map
coords = [40.66970,-122.09596]

#Create the map
my_map = folium.Map(location = coords, zoom_start=8, width=500, height=250)

#GeoJSON marker overlays
folium.GeoJson(data_dict, name="geojson").add_to(my_map)   

#toggle layers
folium.LayerControl().add_to(my_map)  

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_886d7250a54849e5abdcebb4e5388f47%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20500.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20250.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_886d7250a54849e5abdcebb4e5388f47%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_886d7250a54849e5abdcebb4e5388f47%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_886d7250a54849e5abdcebb4e5388f47%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.6697%2C%20-122.09596%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# <a href = "https://nbviewer.org/github/BurnPro3D/data-api-notebooks/blob/main/access-historical-fire-perimeter-data.ipynb">view map using nbviewer</a>
